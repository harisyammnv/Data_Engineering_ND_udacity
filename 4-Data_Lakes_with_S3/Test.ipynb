# %%
import configparser
from datetime import datetime
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import udf, col
from pyspark.sql.functions import year, month, dayofmonth, hour, weekofyear, date_format
from pyspark.sql import functions as F
import zipfile

# %%
spark = SparkSession \
    .builder \
    .config("spark.jars.packages", "org.apache.hadoop:hadoop-aws:2.7.0") \
    .getOrCreate()

# %% [markdown]
# ## Reading Songs Data

# %%
df_full_songs = spark.read.json('./data/song_data/*/*/*/*.json')

# %%
df_full_songs.limit(5).toPandas()
# Out:
#             artist_id  artist_latitude           artist_location  \
# 0  ARDR4AC1187FB371A1              NaN
# 1  AREBBGV1187FB523D2              NaN               Houston, TX
# 2  ARMAC4T1187FB3FA4C         40.82624         Morris Plains, NJ
# 3  ARPBNLO1187FB3D52F         40.71455              New York, NY
# 4  ARNF6401187FB57032         40.79086  New York, NY [Manhattan]
#
#    artist_longitude                                        artist_name  \
# 0               NaN  Montserrat Caballé;Placido Domingo;Vicente Sar...
# 1               NaN       Mike Jones (Featuring CJ_ Mello & Lil' Bran)
# 2         -74.47995                          The Dillinger Escape Plan
# 3         -74.00712                                           Tiny Tim
# 4         -73.96644                                  Sophie B. Hawkins
#
#     duration  num_songs             song_id  \
# 0  511.16363          1  SOBAYLL12A8C138AF9
# 1  173.66159          1  SOOLYAZ12A6701F4A6
# 2  207.77751          1  SOBBUGU12A8C13E95D
# 3   43.36281          1  SOAOIBZ12AB01815BE
# 4  305.16200          1  SONWXQJ12A8C134D94
#
#                                                title  year
# 0                    Sono andati? Fingevo di dormire     0
# 1                    Laws Patrolling (Album Version)     0
# 2                    Setting Fire to Sleeping Giants  2004
# 3  I Hold Your Hand In Mine [Live At Royal Albert...  2000
# 4                      The Ballad Of Sleeping Beauty  1994

# %%
df_full_songs.printSchema()
# Out:
# root
#  |-- artist_id: string (nullable = true)
#  |-- artist_latitude: double (nullable = true)
#  |-- artist_location: string (nullable = true)
#  |-- artist_longitude: double (nullable = true)
#  |-- artist_name: string (nullable = true)
#  |-- duration: double (nullable = true)
#  |-- num_songs: long (nullable = true)
#  |-- song_id: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- year: long (nullable = true)

# %%
def create_select_exprs(json_cols: list, schema_cols: list) -> list:
    exprs = ["{} as {}".format(dfc, sc) for dfc, sc in zip(json_cols, schema_cols)]
    return exprs

# %%
songs = df_full_songs.selectExpr(create_select_exprs(['song_id', 'title', 'artist_id', 'year', 'duration'], ['song_id', 'title', 'artist_id', 'year', 'duration'])).distinct()

# %%
songs.limit(10).toPandas()
# Out:
#               song_id                                              title  \
# 0  SOGOSOV12AF72A285E                                  ¿Dónde va Chichi?
# 1  SOTTDKS12AB018D69B                               It Wont Be Christmas
# 2  SOBBUGU12A8C13E95D                    Setting Fire to Sleeping Giants
# 3  SOIAZJW12AB01853F1                                         Pink World
# 4  SONYPOM12A8C13B2D7  I Think My Wife Is Running Around On Me (Taco ...
# 5  SOYMRWW12A6D4FAB14        The Moon And I (Ordinary Day Album Version)
# 6  SOAOIBZ12AB01815BE  I Hold Your Hand In Mine [Live At Royal Albert...
# 7  SOBCOSW12A8C13D398                                 Rumba De Barcelona
# 8  SOWTBJW12AC468AC6E                         Broken-Down Merry-Go-Round
# 9  SOQHXMF12AB0182363                                    Young Boy Blues
#
#             artist_id  year   duration
# 0  ARGUVEV1187B98BA17  1997  313.12934
# 1  ARMBR4Y1187B9990EB     0  241.47546
# 2  ARMAC4T1187FB3FA4C  2004  207.77751
# 3  AR8ZCNI1187B9A069B  1984  269.81832
# 4  ARDNS031187B9924F0  2005  186.48771
# 5  ARKFYS91187B98E58F     0  267.70240
# 6  ARPBNLO1187FB3D52F  2000   43.36281
# 7  AR7SMBG1187B9B9066     0  218.38322
# 8  ARQGYP71187FB44566     0  151.84934
# 9  ARGSJW91187B9B1D6B     0  218.77506

# %%
artists = df_full_songs.selectExpr(create_select_exprs(["artist_id", "artist_name", "coalesce(nullif(artist_location, ''), 'N/A')", "coalesce(artist_latitude, 0.0)", "coalesce(artist_longitude, 0.0)"],['artist_id', 'name', 'location', 'latitude', 'longitude'])).distinct()
artists.limit(10).toPandas()
# Out:
#             artist_id                                          name  \
# 0  ARPBNLO1187FB3D52F                                      Tiny Tim
# 1  ARBGXIG122988F409D                                    Steel Rain
# 2  AREVWGE1187B9B890A                                    Bitter End
# 3  ARH4Z031187B9A71F2                                    Faye Adams
# 4  ARKFYS91187B98E58F                         Jeff And Sheri Easter
# 5  ARD7TVE1187B99BFB1                                        Casual
# 6  ARHHO3O1187B989413                                     Bob Azzam
# 7  AREBBGV1187FB523D2  Mike Jones (Featuring CJ_ Mello & Lil' Bran)
# 8  ARULZCI1241B9C8611                            Luna Orbit Project
# 9  ARGSJW91187B9B1D6B                                  JennyAnyKind
#
#           location  latitude  longitude
# 0     New York, NY  40.71455  -74.00712
# 1  California - SF  37.77916 -122.42005
# 2        Noci (BA) -13.44200  -41.99520
# 3       Newark, NJ  40.73197  -74.17418
# 4              N/A   0.00000    0.00000
# 5  California - LA   0.00000    0.00000
# 6              N/A   0.00000    0.00000
# 7      Houston, TX   0.00000    0.00000
# 8              N/A   0.00000    0.00000
# 9   North Carolina  35.21962  -80.01955

# %% [markdown]
# ## Reading Logs Data

# %%
df_full = spark.read.format("json").load("./data/log-data/*.json")

# %%
df_full.limit(5).toPandas()
# Out:
#         artist       auth firstName gender  itemInSession lastName     length  \
# 0     Harmonia  Logged In      Ryan      M              0    Smith  655.77751
# 1  The Prodigy  Logged In      Ryan      M              1    Smith  260.07465
# 2        Train  Logged In      Ryan      M              2    Smith  205.45261
# 3         None  Logged In     Wyatt      M              0    Scott        NaN
# 4         None  Logged In    Austin      M              0  Rosales        NaN
#
#   level                               location method      page  registration  \
# 0  free     San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong  1.541017e+12
# 1  free     San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong  1.541017e+12
# 2  free     San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong  1.541017e+12
# 3  free              Eureka-Arcata-Fortuna, CA    GET      Home  1.540872e+12
# 4  free  New York-Newark-Jersey City, NY-NJ-PA    GET      Home  1.541060e+12
#
#    sessionId             song  status             ts  \
# 0        583    Sehr kosmisch     200  1542241826796
# 1        583  The Big Gundown     200  1542242481796
# 2        583         Marry Me     200  1542242741796
# 3        563             None     200  1542247071796
# 4        521             None     200  1542252577796
#
#                                            userAgent userId
# 0  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 1  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 2  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...     26
# 3  Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7....      9
# 4  Mozilla/5.0 (Windows NT 6.1; rv:31.0) Gecko/20...     12

# %%
df_full = df_full.filter(df_full["page"]=='NextSong')

# %%
df_full.limit(5).toPandas()
# Out:
#         artist       auth firstName gender  itemInSession  lastName  \
# 0     Harmonia  Logged In      Ryan      M              0     Smith
# 1  The Prodigy  Logged In      Ryan      M              1     Smith
# 2        Train  Logged In      Ryan      M              2     Smith
# 3  Sony Wonder  Logged In    Samuel      M              0  Gonzalez
# 4    Van Halen  Logged In     Tegan      F              2    Levine
#
#       length level                              location method      page  \
# 0  655.77751  free    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 1  260.07465  free    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 2  205.45261  free    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 3  218.06975  free  Houston-The Woodlands-Sugar Land, TX    PUT  NextSong
# 4  289.38404  paid           Portland-South Portland, ME    PUT  NextSong
#
#    registration  sessionId                                            song  \
# 0  1.541017e+12        583                                   Sehr kosmisch
# 1  1.541017e+12        583                                 The Big Gundown
# 2  1.541017e+12        583                                        Marry Me
# 3  1.540493e+12        597                                       Blackbird
# 4  1.540794e+12        602  Best Of Both Worlds (Remastered Album Version)
#
#    status             ts                                          userAgent  \
# 0     200  1542241826796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 1     200  1542242481796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 2     200  1542242741796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 3     200  1542253449796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4     200  1542260935796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
#   userId
# 0     26
# 1     26
# 2     26
# 3     61
# 4     80

# %%
schema_cols = ['user_id', 'first_name', 'last_name', 'gender', 'level']
df_cols = ['userId', 'firstName', 'lastName', 'gender', 'level']

# %%
users = df_full.selectExpr(create_select_exprs(df_cols, schema_cols)).distinct()

# %%
users.count()
# Out:
# 104

# %%
import datetime

# %%
get_timestamp = udf(lambda x : datetime.datetime.fromtimestamp(x/ 1000.0).strftime("%Y-%m-%d %H:%M:%S"))

# %%
df_full = df_full.withColumn("date_time", get_timestamp(df_full['ts']))

# %%
df_full.limit(5).toPandas()
# Out:
#         artist       auth firstName gender  itemInSession  lastName  \
# 0     Harmonia  Logged In      Ryan      M              0     Smith
# 1  The Prodigy  Logged In      Ryan      M              1     Smith
# 2        Train  Logged In      Ryan      M              2     Smith
# 3  Sony Wonder  Logged In    Samuel      M              0  Gonzalez
# 4    Van Halen  Logged In     Tegan      F              2    Levine
#
#       length level                              location method      page  \
# 0  655.77751  free    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 1  260.07465  free    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 2  205.45261  free    San Jose-Sunnyvale-Santa Clara, CA    PUT  NextSong
# 3  218.06975  free  Houston-The Woodlands-Sugar Land, TX    PUT  NextSong
# 4  289.38404  paid           Portland-South Portland, ME    PUT  NextSong
#
#    registration  sessionId                                            song  \
# 0  1.541017e+12        583                                   Sehr kosmisch
# 1  1.541017e+12        583                                 The Big Gundown
# 2  1.541017e+12        583                                        Marry Me
# 3  1.540493e+12        597                                       Blackbird
# 4  1.540794e+12        602  Best Of Both Worlds (Remastered Album Version)
#
#    status             ts                                          userAgent  \
# 0     200  1542241826796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 1     200  1542242481796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 2     200  1542242741796  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...
# 3     200  1542253449796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
# 4     200  1542260935796  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...
#
#   userId            date_time
# 0     26  2018-11-15 00:30:26
# 1     26  2018-11-15 00:41:21
# 2     26  2018-11-15 00:45:41
# 3     61  2018-11-15 03:44:09
# 4     80  2018-11-15 05:48:55

# %%
def create_extract_select_exprs(json_cols: list, schema_cols: list, extract_col: str) -> list:
    exprs = ["{}({}) as {}".format(dfc, extract_col,sc) for dfc, sc in zip(json_cols, schema_cols)]
    return exprs

# %%
time_exprs = ['date_time as start_time'] + create_extract_select_exprs(['hour', 'dayofmonth', 'weekofyear', 'month', 'year', 'dayofweek'],['hour', 'day', 'week', 'month', 'year', 'weekday'],'date_time')

# %%
time_df = df_full.selectExpr(time_exprs).distinct()

# %%
time_df.limit(5).toPandas()
# Out:
#             start_time  hour  day  week  month  year  weekday
# 0  2018-11-15 12:38:03    12   15    46     11  2018        5
# 1  2018-11-15 22:00:58    22   15    46     11  2018        5
# 2  2018-11-21 19:00:45    19   21    47     11  2018        4
# 3  2018-11-21 20:22:17    20   21    47     11  2018        4
# 4  2018-11-21 22:26:57    22   21    47     11  2018        4

# %%
songs= songs.withColumnRenamed("artist_id", "songs_artist_id")


artists = artists.withColumnRenamed("artist_id", "artists_artist_id") \
                       .withColumnRenamed("location", "artist_location")

# %%
songplays_table = df_full.select(df_full.date_time.alias("start_time"), 
                             df_full.userId.alias("user_id"), 
                             "level", 
                             "song", 
                             "artist", 
                             df_full.sessionId.alias("session_id"), 
                             "location",
                             df_full.userAgent.alias("user_agent")) \
                    .join(songs, df_full.song==songs.title, 'left_outer')   \
                    .join(artists, df_full.artist==artists.name, 'left_outer') \
                    .selectExpr("start_time",
                                "user_id",
                                "level",
                                "song_id",
                                "coalesce(artists_artist_id, songs_artist_id) as artist_id",
                                "session_id",
                                "location",
                                "user_agent",
                                "year(start_time) as year",
                                "month(start_time) as month") \
                    .dropDuplicates() \
                    .withColumn('songplay_id', F.monotonically_increasing_id())

# %%
songplays_table.limit(5).toPandas()
# Out:
#             start_time user_id level song_id artist_id  session_id  \
# 0  2018-11-15 11:29:21      16  paid    None      None         575
# 1  2018-11-15 17:29:48      97  paid    None      None         605
# 2  2018-11-15 19:11:24      42  paid    None      None         404
# 3  2018-11-15 19:30:17      44  paid    None      None         619
# 4  2018-11-15 19:35:33      97  paid    None      None         605
#
#                                 location  \
# 0                  Birmingham-Hoover, AL
# 1               Lansing-East Lansing, MI
# 2  New York-Newark-Jersey City, NY-NJ-PA
# 3               Waterloo-Cedar Falls, IA
# 4               Lansing-East Lansing, MI
#
#                                           user_agent  year  month  songplay_id
# 0  "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4...  2018     11            0
# 1  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...  2018     11            1
# 2  "Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebK...  2018     11            2
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; r...  2018     11            3
# 4  "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/5...  2018     11            4
